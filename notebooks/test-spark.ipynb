# %%
import sys
sys.path.append('/home/mihailcho/lakehouse')
import pandas as pd
from conf.spark_config import get_spark_session
spark = get_spark_session('test')




# df = spark.sql("select _ingestion_timestamp, count(*) from nessie.bronze.ss5_web_app_clicks group by _ingestion_timestamp")
# df.show(truncate=False)

# spark.sql("delete from nessie.meta.file_ingestion_log")
# spark.sql("delete from nessie.meta.db_ingestion_log")
# spark.sql("drop table  nessie.bronze.ss1_companies")

# df = spark.sql("select * from nessie.bronze.ss1_companies")
# df.show(truncate=False)

spark.stop()

# %%
spark = get_spark_session('test')




# df = spark.sql("select _ingestion_timestamp, count(*) from nessie.bronze.ss5_web_app_clicks group by _ingestion_timestamp")
# df.show(truncate=False)

df = spark.sql("select * from nessie.bronze.ss1_companies order by _ingestion_timestamp asc")
df.show(truncate=False)

spark.stop()
# Out:
# +----------+-------------------------+------------+------------+-----------+---------+-------------------+-----------+--------+---------+------------+------------------+--------------+--------------------------+---------------------------------------------------------+--------------+
# |company_id|company_name             |company_code|company_type|country    |city     |address            |postal_code|currency|is_active|founded_date|ceo_name          |_source_system|_ingestion_timestamp      |_source_file                                             |employee_count|
# +----------+-------------------------+------------+------------+-----------+---------+-------------------+-----------+--------+---------+------------+------------------+--------------+--------------------------+---------------------------------------------------------+--------------+
# |1         |MishoSales Holding AG    |MSHA        |Holding     |Switzerland|Zurich   |Bahnhofstrasse 1   |8001       |CHF     |true     |2001-03-15  |Elena Petrova     |ss1           |2026-06-07 13:01:14.42146 |/home/mihailcho/lakehouse/data/ss1/companies_20260531.csv|NULL          |
# |2         |MishoSales Central Europe|MSCE        |Regional    |Germany    |Munich   |Leopoldstrasse 22  |80802      |EUR     |true     |2003-06-01  |Hans Müller       |ss1           |2026-06-07 13:01:14.42146 |/home/mihailcho/lakehouse/data/ss1/companies_20260531.csv|NULL          |
# |3         |MishoSales Eastern Europe|MSEE        |Regional    |Bulgaria   |Sofia    |Vitosha Blvd 45    |1000       |BGN     |true     |2005-09-10  |Georgi Ivanov     |ss1           |2026-06-07 13:01:14.42146 |/home/mihailcho/lakehouse/data/ss1/companies_20260531.csv|NULL          |
# |4         |MishoSales Adriatic      |MSAD        |Regional    |Croatia    |Zagreb   |Ilica 12           |10000      |EUR     |true     |2007-11-20  |Marko Horvat      |ss1           |2026-06-07 13:01:14.42146 |/home/mihailcho/lakehouse/data/ss1/companies_20260531.csv|NULL          |
# |5         |MishoSales Balkans       |MSBA        |Regional    |Serbia     |Belgrade |Knez Mihailova 8   |11000      |RSD     |true     |2008-04-05  |Milica Jovic      |ss1           |2026-06-07 13:01:14.42146 |/home/mihailcho/lakehouse/data/ss1/companies_20260531.csv|NULL          |
# |6         |MishoSales Online        |MSOL        |eCommerce   |Germany    |Berlin   |Unter den Linden 5 |10117      |EUR     |true     |2012-01-01  |Sophie Weber      |ss1           |2026-06-07 13:01:14.42146 |/home/mihailcho/lakehouse/data/ss1/companies_20260531.csv|NULL          |
# |7         |MishoSales Franchise GmbH|MSFR        |Franchise   |Austria    |Vienna   |Mariahilfer Str 88 |1060       |EUR     |true     |2010-07-15  |Klaus Fischer     |ss1           |2026-06-07 13:01:14.42146 |/home/mihailcho/lakehouse/data/ss1/companies_20260531.csv|NULL          |
#